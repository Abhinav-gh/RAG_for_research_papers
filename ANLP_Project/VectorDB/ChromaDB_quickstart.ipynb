# %% [markdown]
# ### DBMS Init

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.0.20-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pydantic>=1.9 (from chromadb)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.2-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from chromadb) (2.2.3)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.22.1-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Downloading tokenizers-0.22.0-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from chromadb) (7.7.0)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.74.0-cp311-cp311-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.3.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.17.3-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting tenacity>=8.2.3 (from chromadb)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting orjson>=3.9.12 (from chromadb)
#   Downloading orjson-3.11.3-cp311-cp311-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from chromadb) (0.28.1)
# Collecting rich>=10.11.0 (from chromadb)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from httpx>=0.27.0->chromadb) (4.8.0)
# Requirement already satisfied: certifi in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.23.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: sympy in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.36.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.57b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting distro>=1.5.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=1.9->chromadb)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=1.9->chromadb)
#   Downloading pydantic_core-2.33.2-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic>=1.9->chromadb)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb)
#   Downloading huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.0-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: filelock in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.0)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading chromadb-1.0.20-cp39-abi3-win_amd64.whl (19.8 MB)
#    ---------------------------------------- 0.0/19.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.8 MB 1.2 MB/s eta 0:00:17
#    - -------------------------------------- 0.8/19.8 MB 1.2 MB/s eta 0:00:17
#    -- ------------------------------------- 1.0/19.8 MB 1.2 MB/s eta 0:00:16
#    -- ------------------------------------- 1.3/19.8 MB 1.3 MB/s eta 0:00:15
#    --- ------------------------------------ 1.6/19.8 MB 1.3 MB/s eta 0:00:14
#    --- ------------------------------------ 1.8/19.8 MB 1.3 MB/s eta 0:00:15
#    ---- ----------------------------------- 2.4/19.8 MB 1.4 MB/s eta 0:00:13
#    ----- ---------------------------------- 2.6/19.8 MB 1.4 MB/s eta 0:00:13
#    ----- ---------------------------------- 2.9/19.8 MB 1.4 MB/s eta 0:00:13
#    ------ --------------------------------- 3.1/19.8 MB 1.4 MB/s eta 0:00:13
#    ------ --------------------------------- 3.4/19.8 MB 1.4 MB/s eta 0:00:12
#    ------- -------------------------------- 3.7/19.8 MB 1.4 MB/s eta 0:00:12
#    -------- ------------------------------- 4.2/19.8 MB 1.4 MB/s eta 0:00:12
#    --------- ------------------------------ 4.5/19.8 MB 1.4 MB/s eta 0:00:12
#    --------- ------------------------------ 4.5/19.8 MB 1.4 MB/s eta 0:00:12
#    ---------- ----------------------------- 5.0/19.8 MB 1.4 MB/s eta 0:00:11
#    ---------- ----------------------------- 5.2/19.8 MB 1.4 MB/s eta 0:00:11
#    ----------- ---------------------------- 5.5/19.8 MB 1.4 MB/s eta 0:00:11
#    ----------- ---------------------------- 5.8/19.8 MB 1.4 MB/s eta 0:00:11
#    ------------ --------------------------- 6.0/19.8 MB 1.4 MB/s eta 0:00:10
#    ------------ --------------------------- 6.3/19.8 MB 1.4 MB/s eta 0:00:10
#    ------------- -------------------------- 6.8/19.8 MB 1.4 MB/s eta 0:00:10
#    -------------- ------------------------- 7.1/19.8 MB 1.4 MB/s eta 0:00:10
#    -------------- ------------------------- 7.3/19.8 MB 1.4 MB/s eta 0:00:09
#    --------------- ------------------------ 7.9/19.8 MB 1.4 MB/s eta 0:00:09
#    ---------------- ----------------------- 8.1/19.8 MB 1.4 MB/s eta 0:00:09
#    ---------------- ----------------------- 8.4/19.8 MB 1.4 MB/s eta 0:00:09
#    ----------------- ---------------------- 8.7/19.8 MB 1.4 MB/s eta 0:00:08
#    ------------------ --------------------- 8.9/19.8 MB 1.4 MB/s eta 0:00:08
#    ------------------ --------------------- 9.2/19.8 MB 1.4 MB/s eta 0:00:08
#    ------------------- -------------------- 9.4/19.8 MB 1.4 MB/s eta 0:00:08
#    ------------------- -------------------- 9.7/19.8 MB 1.4 MB/s eta 0:00:08
#    -------------------- ------------------- 10.2/19.8 MB 1.4 MB/s eta 0:00:07
#    --------------------- ------------------ 10.5/19.8 MB 1.4 MB/s eta 0:00:07
#    --------------------- ------------------ 10.7/19.8 MB 1.4 MB/s eta 0:00:07
#    ---------------------- ----------------- 11.0/19.8 MB 1.4 MB/s eta 0:00:07
#    ---------------------- ----------------- 11.3/19.8 MB 1.4 MB/s eta 0:00:07
#    ----------------------- ---------------- 11.8/19.8 MB 1.4 MB/s eta 0:00:06
#    ------------------------ --------------- 12.1/19.8 MB 1.4 MB/s eta 0:00:06
#    ------------------------ --------------- 12.3/19.8 MB 1.4 MB/s eta 0:00:06
#    ------------------------- -------------- 12.8/19.8 MB 1.4 MB/s eta 0:00:05
#    -------------------------- ------------- 13.1/19.8 MB 1.4 MB/s eta 0:00:05
#    --------------------------- ------------ 13.4/19.8 MB 1.4 MB/s eta 0:00:05
#    --------------------------- ------------ 13.6/19.8 MB 1.4 MB/s eta 0:00:05
#    ---------------------------- ----------- 14.2/19.8 MB 1.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 14.4/19.8 MB 1.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 14.7/19.8 MB 1.4 MB/s eta 0:00:04
#    ------------------------------ --------- 14.9/19.8 MB 1.4 MB/s eta 0:00:04
#    ------------------------------ --------- 15.2/19.8 MB 1.4 MB/s eta 0:00:04
#    ------------------------------- -------- 15.5/19.8 MB 1.4 MB/s eta 0:00:04
#    -------------------------------- ------- 16.0/19.8 MB 1.4 MB/s eta 0:00:03
#    -------------------------------- ------- 16.3/19.8 MB 1.4 MB/s eta 0:00:03
#    --------------------------------- ------ 16.5/19.8 MB 1.4 MB/s eta 0:00:03
#    --------------------------------- ------ 16.8/19.8 MB 1.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 17.0/19.8 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 17.3/19.8 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 17.6/19.8 MB 1.4 MB/s eta 0:00:02
#    ------------------------------------ --- 17.8/19.8 MB 1.4 MB/s eta 0:00:02
#    ------------------------------------ --- 18.1/19.8 MB 1.4 MB/s eta 0:00:02
#    ------------------------------------- -- 18.6/19.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 18.9/19.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 19.1/19.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  19.7/19.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  19.7/19.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 19.8/19.8 MB 1.4 MB/s eta 0:00:00
# Downloading bcrypt-4.3.0-cp39-abi3-win_amd64.whl (152 kB)
# Downloading build-1.3.0-py3-none-any.whl (23 kB)
# Downloading grpcio-1.74.0-cp311-cp311-win_amd64.whl (4.5 MB)
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.5 MB 882.6 kB/s eta 0:00:05
#    ------ --------------------------------- 0.8/4.5 MB 987.4 kB/s eta 0:00:04
#    ----------- ---------------------------- 1.3/4.5 MB 1.2 MB/s eta 0:00:03
#    ------------- -------------------------- 1.6/4.5 MB 1.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 1.8/4.5 MB 1.3 MB/s eta 0:00:03
#    ------------------ --------------------- 2.1/4.5 MB 1.2 MB/s eta 0:00:02
#    -------------------- ------------------- 2.4/4.5 MB 1.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.6/4.5 MB 1.3 MB/s eta 0:00:02
#    ------------------------- -------------- 2.9/4.5 MB 1.3 MB/s eta 0:00:02
#    --------------------------- ------------ 3.1/4.5 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 3.4/4.5 MB 1.3 MB/s eta 0:00:01
#    -------------------------------- ------- 3.7/4.5 MB 1.2 MB/s eta 0:00:01
#    -------------------------------- ------- 3.7/4.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.9/4.5 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 4.2/4.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 1.2 MB/s eta 0:00:00
# Downloading kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/1.9 MB 1.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 0.8/1.9 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.9 MB 1.1 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.9 MB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/1.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 1.1 MB/s eta 0:00:00
# Downloading mmh3-5.2.0-cp311-cp311-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.22.1-cp311-cp311-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.7 MB 989.2 kB/s eta 0:00:13
#    -- ------------------------------------- 0.8/12.7 MB 1.0 MB/s eta 0:00:12
#    --- ------------------------------------ 1.0/12.7 MB 1.0 MB/s eta 0:00:12
#    ---- ----------------------------------- 1.3/12.7 MB 1.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.6/12.7 MB 1.1 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.8/12.7 MB 1.1 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.8/12.7 MB 1.1 MB/s eta 0:00:10
#    ------ --------------------------------- 2.1/12.7 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.4/12.7 MB 1.1 MB/s eta 0:00:10
#    -------- ------------------------------- 2.6/12.7 MB 1.1 MB/s eta 0:00:10
#    --------- ------------------------------ 2.9/12.7 MB 1.0 MB/s eta 0:00:10
#    --------- ------------------------------ 2.9/12.7 MB 1.0 MB/s eta 0:00:10
#    --------- ------------------------------ 3.1/12.7 MB 1.1 MB/s eta 0:00:10
#    ---------- ----------------------------- 3.4/12.7 MB 1.0 MB/s eta 0:00:09
#    ----------- ---------------------------- 3.7/12.7 MB 1.0 MB/s eta 0:00:09
#    ------------ --------------------------- 3.9/12.7 MB 1.1 MB/s eta 0:00:09
#    ------------- -------------------------- 4.2/12.7 MB 1.0 MB/s eta 0:00:09
#    -------------- ------------------------- 4.5/12.7 MB 1.1 MB/s eta 0:00:08
#    -------------- ------------------------- 4.7/12.7 MB 1.1 MB/s eta 0:00:08
#    ---------------- ----------------------- 5.2/12.7 MB 1.1 MB/s eta 0:00:07
#    ---------------- ----------------------- 5.2/12.7 MB 1.1 MB/s eta 0:00:07
#    ----------------- ---------------------- 5.5/12.7 MB 1.1 MB/s eta 0:00:07
#    ------------------ --------------------- 5.8/12.7 MB 1.1 MB/s eta 0:00:07
#    ------------------- -------------------- 6.0/12.7 MB 1.1 MB/s eta 0:00:06
#    ------------------- -------------------- 6.3/12.7 MB 1.1 MB/s eta 0:00:06
#    -------------------- ------------------- 6.6/12.7 MB 1.1 MB/s eta 0:00:06
#    --------------------- ------------------ 6.8/12.7 MB 1.1 MB/s eta 0:00:06
#    --------------------- ------------------ 6.8/12.7 MB 1.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 7.1/12.7 MB 1.1 MB/s eta 0:00:06
#    ----------------------- ---------------- 7.3/12.7 MB 1.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 7.6/12.7 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 7.9/12.7 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 8.1/12.7 MB 1.1 MB/s eta 0:00:05
#    -------------------------- ------------- 8.4/12.7 MB 1.1 MB/s eta 0:00:04
#    --------------------------- ------------ 8.7/12.7 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 9.2/12.7 MB 1.1 MB/s eta 0:00:04
#    ----------------------------- ---------- 9.4/12.7 MB 1.1 MB/s eta 0:00:03
#    ------------------------------ --------- 9.7/12.7 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 10.0/12.7 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 10.2/12.7 MB 1.2 MB/s eta 0:00:03
#    --------------------------------- ------ 10.5/12.7 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.7 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.7 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 11.5/12.7 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.7 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.7 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.7 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.7 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 1.2 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.36.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.36.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl (119 kB)
# Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl (201 kB)
# Downloading orjson-3.11.3-cp311-cp311-win_amd64.whl (131 kB)
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Downloading pybase64-1.4.2-cp311-cp311-win_amd64.whl (35 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 1.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 0.8/2.0 MB 1.0 MB/s eta 0:00:02
#    --------------------- ------------------ 1.0/2.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.1 MB/s eta 0:00:00
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading tokenizers-0.22.0-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 1.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.7 MB 1.2 MB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.7 MB 1.0 MB/s eta 0:00:02
#    ------------------- -------------------- 1.3/2.7 MB 1.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 1.6/2.7 MB 1.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 1.6/2.7 MB 1.1 MB/s eta 0:00:02
#    --------------------------- ------------ 1.8/2.7 MB 1.0 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.7 MB 1.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 1.0 MB/s eta 0:00:00
# Downloading typer-0.17.3-py3-none-any.whl (46 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Using cached google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Using cached googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading httptools-0.6.4-cp311-cp311-win_amd64.whl (88 kB)
# Downloading huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#    ---------------------------------------- 0.0/561.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/561.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/561.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/561.5 kB ? eta -:--:--
#    ---------------------------------------- 561.5/561.5 kB 1.0 MB/s eta 0:00:00
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl (435 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading watchfiles-1.1.0-cp311-cp311-win_amd64.whl (292 kB)
# Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53916 sha256=5e6cb9e7a4949397134a6a0beb0625e84bec456d16893ce114ec15dfeeb8901e
#   Stored in directory: c:\users\micro\appdata\local\pip\cache\wheels\a3\01\bd\4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, flatbuffers, durationpy, zipp, websockets, typing-inspection, tenacity, shellingham, python-dotenv, pyreadline3, pyproject_hooks, pydantic-core, pybase64, pyasn1, protobuf, orjson, oauthlib, mmh3, mdurl, importlib-resources, httptools, grpcio, distro, cachetools, bcrypt, backoff, annotated-types, watchfiles, uvicorn, rsa, requests-oauthlib, pydantic, pyasn1-modules, posthog, opentelemetry-proto, markdown-it-py, importlib-metadata, humanfriendly, huggingface-hub, googleapis-common-protos, build, tokenizers, rich, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, google-auth, coloredlogs, typer, opentelemetry-semantic-conventions, onnxruntime, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
# Successfully installed annotated-types-0.7.0 backoff-2.2.1 bcrypt-4.3.0 build-1.3.0 cachetools-5.5.2 chromadb-1.0.20 coloredlogs-15.0.1 distro-1.9.0 durationpy-0.10 flatbuffers-25.2.10 google-auth-2.40.3 googleapis-common-protos-1.70.0 grpcio-1.74.0 httptools-0.6.4 huggingface-hub-0.34.4 humanfriendly-10.0 importlib-metadata-8.7.0 importlib-resources-6.5.2 kubernetes-33.1.0 markdown-it-py-4.0.0 mdurl-0.1.2 mmh3-5.2.0 oauthlib-3.3.1 onnxruntime-1.22.1 opentelemetry-api-1.36.0 opentelemetry-exporter-otlp-proto-common-1.36.0 opentelemetry-exporter-otlp-proto-grpc-1.36.0 opentelemetry-proto-1.36.0 opentelemetry-sdk-1.36.0 opentelemetry-semantic-conventions-0.57b0 orjson-3.11.3 posthog-5.4.0 protobuf-6.32.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pybase64-1.4.2 pydantic-2.11.7 pydantic-core-2.33.2 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 python-dotenv-1.1.1 requests-oauthlib-2.0.0 rich-14.1.0 rsa-4.9.1 shellingham-1.5.4 tenacity-9.1.2 tokenizers-0.22.0 typer-0.17.3 typing-inspection-0.4.1 uvicorn-0.35.0 watchfiles-1.1.0 websockets-15.0.1 zipp-3.23.0

# %% [markdown]
# Path to store the database at

# %%
from pathlib import Path
import chromadb

Relative_Database_path = "./chroma_Data" # Relative
Absolute_Database_path = Path(Relative_Database_path).resolve()
client = chromadb.PersistentClient(path=Absolute_Database_path)
print("[INFO] Absolute Path to database: ", Absolute_Database_path)
# Out:
# [INFO] Absolute Path to database:  C:\Users\micro\Desktop\Abhinav college\Resources\Sem 7\Advanced NLP\RAG_for_research_papers\VectorDB\chroma_Data

# %%
client = chromadb.PersistentClient(path=Absolute_Database_path)

print("[INFO] Client: ", client, "initialized")
# Out:
# [INFO] Client:  <chromadb.api.client.Client object at 0x0000017755CFD350> initialized

# %%
collections = client.list_collections()
print("Collections of this client: ", collections)
# Out:
# Collections of this client:  [Collection(name=my_collection)]

# %% [markdown]
# ### Creating first collection.
# A collection is analogous to a table in a relational DBMS. eg. a collection of knowledge.
#
# You can only query one collection at a time. Thus, we will have one collection for the whole RAG.

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence_transformers-5.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence_transformers)
#   Downloading transformers-4.56.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: tqdm in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from sentence_transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from sentence_transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from sentence_transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from sentence_transformers) (0.34.4)
# Requirement already satisfied: Pillow in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from sentence_transformers) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from sentence_transformers) (4.12.2)
# Requirement already satisfied: filelock in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: networkx in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.2.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.22.0)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence_transformers)
#   Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2025.1.31)
# Downloading sentence_transformers-5.1.0-py3-none-any.whl (483 kB)
# Downloading transformers-4.56.0-py3-none-any.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.6 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/11.6 MB 1.3 MB/s eta 0:00:09
#    --- ------------------------------------ 1.0/11.6 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/11.6 MB 1.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/11.6 MB 1.4 MB/s eta 0:00:08
#    ------- -------------------------------- 2.1/11.6 MB 1.4 MB/s eta 0:00:07
#    -------- ------------------------------- 2.4/11.6 MB 1.4 MB/s eta 0:00:07
#    --------- ------------------------------ 2.6/11.6 MB 1.4 MB/s eta 0:00:07
#    --------- ------------------------------ 2.6/11.6 MB 1.4 MB/s eta 0:00:07
#    --------- ------------------------------ 2.9/11.6 MB 1.3 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.4/11.6 MB 1.3 MB/s eta 0:00:07
#    ------------ --------------------------- 3.7/11.6 MB 1.3 MB/s eta 0:00:06
#    ------------- -------------------------- 3.9/11.6 MB 1.3 MB/s eta 0:00:06
#    -------------- ------------------------- 4.2/11.6 MB 1.4 MB/s eta 0:00:06
#    --------------- ------------------------ 4.5/11.6 MB 1.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.7/11.6 MB 1.3 MB/s eta 0:00:06
#    ----------------- ---------------------- 5.0/11.6 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 5.2/11.6 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 5.5/11.6 MB 1.3 MB/s eta 0:00:05
#    ------------------- -------------------- 5.8/11.6 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 6.0/11.6 MB 1.3 MB/s eta 0:00:05
#    --------------------- ------------------ 6.3/11.6 MB 1.3 MB/s eta 0:00:05
#    ---------------------- ----------------- 6.6/11.6 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.8/11.6 MB 1.3 MB/s eta 0:00:04
#    ------------------------ --------------- 7.1/11.6 MB 1.3 MB/s eta 0:00:04
#    ------------------------- -------------- 7.3/11.6 MB 1.3 MB/s eta 0:00:04
#    -------------------------- ------------- 7.6/11.6 MB 1.3 MB/s eta 0:00:04
#    --------------------------- ------------ 7.9/11.6 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.1/11.6 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.4/11.6 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.7/11.6 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 8.9/11.6 MB 1.3 MB/s eta 0:00:03
#    ------------------------------- -------- 9.2/11.6 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 9.4/11.6 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 9.7/11.6 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.0/11.6 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 10.5/11.6 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.6 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.6 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 11.0/11.6 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.6 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 1.3 MB/s eta 0:00:00
# Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl (320 kB)
# Installing collected packages: safetensors, transformers, sentence_transformers
# Successfully installed safetensors-0.6.2 sentence_transformers-5.1.0 transformers-4.56.0

# %%
# Choosing the default embedding function
from chromadb.utils.embedding_functions import SentenceTransformerEmbeddingFunction
embedding_function = SentenceTransformerEmbeddingFunction(model_name="all-MiniLM-L6-v2")
from datetime import datetime

collection = client.get_or_create_collection(
    name="my_collection",
    embedding_function=embedding_function,
    metadata={
        "owner": "Abhinav",
        "description": "my first Chroma collection",
        "created": str(datetime.now())
    },
    configuration={ # This offers more control. Tune parameters to improve performance
        "hnsw:space": "cosine",
        "hnsw:construction_ef": 200,
        "hnsw:M": 16,
        "hnsw:search_ef": 50
    }
)

print("Collection Generated with embedding function:", embedding_function)
# Out:
# Collection Generated with embedding function: <chromadb.utils.embedding_functions.sentence_transformer_embedding_function.SentenceTransformerEmbeddingFunction object at 0x0000017755CA5D50>

# %%
docs = [
    "The Eiffel Tower, a famous landmark, is located in Paris, France.",
    "The Colosseum is in Rome.",
    "The Great Wall of China is visible from space (not really)."
]

metas = [
    {"city": "Paris", "country": "France"},
    {"city": "Rome", "country": "Italy"},
    {"city": "Beijing", "country": "China"}
]

ids = ["doc1", "doc2", "doc3"]

# collection.add(
#     documents=docs,
#     metadatas=metas,
#     ids=ids
# )

collection.update(
    documents=docs,
    metadatas=metas,
    ids=ids
)

# %%
print(collection.count())      # number of items
print(collection.peek())       # first few items
# Out:
# 3
# {'ids': ['doc1', 'doc2', 'doc3'], 'embeddings': array([[ 0.06705675,  0.05626705, -0.00802136, ...,  0.05057557,
#          0.07656233,  0.0231804 ],
#        [ 0.01886094,  0.00550705,  0.03100901, ..., -0.01101136,
#         -0.03171892,  0.05067538],
#        [ 0.05961616,  0.05668674,  0.04932906, ...,  0.01538757,
#         -0.07548427,  0.07908341]], shape=(3, 384)), 'documents': ['The Eiffel Tower, a famous landmark, is located in Paris, France.', 'The Colosseum is in Rome.', 'The Great Wall of China is visible from space (not really).'], 'uris': None, 'included': ['metadatas', 'documents', 'embeddings'], 'data': None, 'metadatas': [{'country': 'France', 'city': 'Paris', 'source': 'test'}, {'country': 'Italy', 'city': 'Rome'}, {'city': 'Beijing', 'country': 'China'}]}

# %% [markdown]
# ### Querying the Database

# %%
# !pip install rich
# Out:
# Requirement already satisfied: rich in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (14.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from rich) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from rich) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\micro\anaconda3\envs\nlp_2\lib\site-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)

# %%
from rich.console import Console
from rich.table import Table

console = Console()

def print_results_table(results):
    table = Table(show_header=True, header_style="bold magenta")
    table.add_column("Rank", style="dim", width=6)
    table.add_column("ID", style="cyan")
    table.add_column("Document", style="green")
    table.add_column("Metadata", style="yellow")
    table.add_column("Distance", justify="right")

    docs = results.get("documents", [[]])[0]
    metas = results.get("metadatas", [[]])[0]
    dists = results.get("distances", [[]])[0]
    ids   = results.get("ids", [[]])[0]

    for i, (doc, meta, dist, _id) in enumerate(zip(docs, metas, dists, ids)):
        table.add_row(
            str(i+1),
            str(_id),
            str(doc),
            str(meta),
            f"{dist:.4f}"
        )

    console.print(table)

# %%
results = collection.query(
    query_texts=["Where is the Eiffel Tower?"],
    n_results=2,
    include=["documents", "metadatas", "distances"]
)

print_results_table(results)
# Out:
# ┏━━━━━━━━┳━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Rank   ┃ ID   ┃ Document                                 ┃ Metadata                                  ┃ Distance ┃
# ┡━━━━━━━━╇━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━┩
# │ 1      │ doc1 │ The Eiffel Tower, a famous landmark, is  │ {'source': 'test', 'city': 'Paris',       │   0.1784 │
# │        │      │ located in Paris, France.                │ 'country': 'France'}                      │          │
# │ 2      │ doc3 │ The Great Wall of China is visible from  │ {'country': 'China', 'city': 'Beijing'}   │   0.7324 │
# │        │      │ space (not really).                      │                                           │          │
# └────────┴──────┴──────────────────────────────────────────┴───────────────────────────────────────────┴──────────┘
